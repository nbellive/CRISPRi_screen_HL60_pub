# %%
import matplotlib.pyplot as plt
# from matplotlib.pyplot import GridSpec
# from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
import glob
import pandas as pd
import math

import FlowCytometryTools
from FlowCytometryTools import FCMeasurement

import seaborn as sns

# %% [markdown]
# ## Construct: SFFV-KRAB-dCas9-P2A-mCherry

# %%
# load in data

# %%
filelist_high = \
["../../data/flow_cytometry/20191206_lenti-dCas9-mChr_CD4kd/HL60_lentidCas9-mCh_sgMYPT1_antiCD4_Data Source - 1.fcs",
 '../../data/flow_cytometry/20191218_lenti-dCas9-mCh-high_CD4kd/HL60_lentidCas9high-sgCD4_antiCD4.fcs',
 '../../data/flow_cytometry/20191218_lenti-dCas9-mCh-high_CD4kd/HL60_lentidCas9high-sgCD4_Ctrl.fcs']

# %%
# files = glob.glob('../../data/flow_cytometry/20220317_KDlines_integrinrelated_repeats/*iso*.fcs')

sample = FCMeasurement(ID='ctrl', datafile=filelist_high[0])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 4E5]
sample = sample[sample['SSC-A'] >= 1.9E5]
sample = sample[sample['SSC-A'] <= 6E5]


fig, ax = plt.subplots(figsize=(5,5))

ax.scatter(sample[['FSC-A']].values, sample[['SSC-A']].values, 
                alpha=0.01, label='wild-type', color = "#3498db")



ax.set_xlim(4E4,1E6)
ax.set_ylim(1E5,1E6)
# ax.set_yscale('log')
# ax.set_xscale('log')
# ax.set_xlabel('FSC (a.u.)', fontsize=20)
# ax.set_ylabel('SSC (a.u.)', fontsize=20)
# ax.tick_params(axis='both', which='major', labelsize=12)
# ax.legend(loc='upper right',fontsize=14)
# Out:
# (100000.0, 1000000.0)

# %%
fig, ax1 = plt.subplots(figsize=(4,3))

sample = FCMeasurement(ID='ctrl', datafile=filelist_high[0])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 4E5]
sample = sample[sample['SSC-A'] >= 1.9E5]
sample = sample[sample['SSC-A'] <= 6E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, #
            lw = 0, alpha = 0.3, legend = False, shade = True)


sample = FCMeasurement(ID='ctrl', datafile=filelist_high[1])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 4E5]
sample = sample[sample['SSC-A'] >= 1.9E5]
sample = sample[sample['SSC-A'] <= 6E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, #color = 'grey',
            lw = 0, alpha = 0.3, legend = False, shade = True)


sample = FCMeasurement(ID='ctrl', datafile=filelist_high[2])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 4E5]
sample = sample[sample['SSC-A'] >= 1.9E5]
sample = sample[sample['SSC-A'] <= 6E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, color = 'grey',
            lw = 0, alpha = 0.3, legend = False, shade = True)


for ax_ in [ax1]:
    ax_.set_yticks([])
    ax_.set_xlim(2,4.6)
    ax_.set_ylim(0,2.2)
    ax_.grid(axis='x', color= 'grey', alpha  = 0.2)#xcolor='0.95')

    # ax_.axes.get_xaxis().set_visible(False)
    ax_.axes.get_yaxis().set_visible(False)
    ax_.set_xlabel(None)
    ax_.set_xticks(np.log10([200,300,400,500,600,700,800,900,
                            2000,3000,4000,5000,6000,7000,8000,9000,
                            20000,30000,40000,50000,60000,70000,80000,90000,
                            200000,300000]), minor = True)
    ax_.set_xticks(np.log10([100,1000, 10000,100000]))
    ax_.set_xticklabels([])
    ax_.tick_params(length=8)

# %% [markdown]
# ## Dox inducible dCas9-mCherry

# %%
filelist = \
['../../data/flow_cytometry/20200227_CD4kd/KW-NDi4x_0umDox_antiCD4.fcs',
'../../data/flow_cytometry/20200227_CD4kd/KW-NDi4x_0umDox_antiCTRL.fcs',
'../../data/flow_cytometry/20200227_CD4kd/KW-NDi4x_2umDox_antiCD4.fcs',
'../../data/flow_cytometry/20200227_CD4kd/KW-NDi4x_2umDox_antiCTRL.fcs']

# %%
sample = FCMeasurement(ID='ctrl', datafile=filelist[0])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 4E5]
sample = sample[sample['SSC-A'] >= 1.5E5]
sample = sample[sample['SSC-A'] <= 4E5]


fig, ax = plt.subplots(figsize=(5,5))

ax.scatter(sample[['FSC-A']].values, sample[['SSC-A']].values, 
                alpha=0.01, label='wild-type', color = "#3498db")



ax.set_xlim(4E4,1E6)
ax.set_ylim(1E5,1E6)
# Out:
# (100000.0, 1000000.0)

# %%
fig, ax1 = plt.subplots(figsize=(4,3))

sample = FCMeasurement(ID='ctrl', datafile=filelist[0])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 4E5]
sample = sample[sample['SSC-A'] >= 1.5E5]
sample = sample[sample['SSC-A'] <= 4E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, #
            lw = 0, alpha = 0.3, legend = False, shade = True,
           label = '0 Dox, anti-CD4')


sample = FCMeasurement(ID='ctrl', datafile=filelist[2])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 4E5]
sample = sample[sample['SSC-A'] >= 1.5E5]
sample = sample[sample['SSC-A'] <= 4E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, #color = 'grey',
            lw = 0, alpha = 0.3, legend = False, shade = True,
           label = '0 Dox, anti-CD4')


sample = FCMeasurement(ID='ctrl', datafile=filelist[3])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 4E5]
sample = sample[sample['SSC-A'] >= 1.5E5]
sample = sample[sample['SSC-A'] <= 4E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, color = 'grey',
            lw = 0, alpha = 0.3, legend = False, shade = True)


for ax_ in [ax1]:
    ax_.set_yticks([])
    ax_.set_xlim(2,4.6)
    ax_.set_ylim(0,3)
    ax_.grid(axis='x', color= 'grey', alpha  = 0.2)#xcolor='0.95')

    # ax_.axes.get_xaxis().set_visible(False)
    ax_.axes.get_yaxis().set_visible(False)
    ax_.set_xlabel(None)
    ax_.set_xticks(np.log10([200,300,400,500,600,700,800,900,
                            2000,3000,4000,5000,6000,7000,8000,9000,
                            20000,30000,40000,50000,60000,70000,80000,90000,
                            200000,300000]), minor = True)
    ax_.set_xticks(np.log10([100,1000, 10000,100000]))
    ax_.set_xticklabels([])
    ax_.tick_params(length=8)

# %% [markdown]
# ### BFP

# %%
# HL60 with dCas9-BFP-KRAB (sorted 3x to obtain BFP+ cells)

# %%
filelist = \
['../../data/flow_cytometry/20200309_CD4_kd/KW-dCas9-BFP-KRAB_antiCD4.fcs',
'../../data/flow_cytometry/20200309_CD4_kd/KW-dCas9-BFP-KRAB_gCD4_antiCD4.fcs',
'../../data/flow_cytometry/20200309_CD4_kd/KW-dCas9-BFP-KRAB_gCD4_antiCTRL.fcs',
'../../../data/facs/20200309_CD4_kd/KW-NDi-clone8_0umDox_antiCD4.fcs',
'../../../data/facs/20200309_CD4_kd/KW-NDi-clone8_gCD4_2umDox_antiCD4.fcs',
'../../../data/facs/20200309_CD4_kd/KW-NDi-clone8_gCD4_2umDox_antiCTRL.fcs',
'../../data/flow_cytometry/20200309_CD4_kd/NDi_5xSort_0uMDox_antiCD4.fcs',
'../../data/flow_cytometry/20200309_CD4_kd/NDi_5xSort_gCD4_2uMDox_antiCD4.fcs',
'../../data/flow_cytometry/20200309_CD4_kd/NDi_5xSort_gCD4_2uMDox_antiCTRL.fcs'
]

# %%
sample = FCMeasurement(ID='ctrl', datafile=filelist[0])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 3.4E5]
sample = sample[sample['SSC-A'] >= 2E5]
sample = sample[sample['SSC-A'] <= 5E5]


fig, ax = plt.subplots(figsize=(5,5))

ax.scatter(sample[['FSC-A']].values, sample[['SSC-A']].values, 
                alpha=0.01, label='wild-type', color = "#3498db")



ax.set_xlim(4E4,1E6)
ax.set_ylim(1E5,1E6)
# Out:
# (100000.0, 1000000.0)

# %%
fig, ax1 = plt.subplots(figsize=(4,3))

sample = FCMeasurement(ID='ctrl', datafile=filelist[0])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 3.4E5]
sample = sample[sample['SSC-A'] >= 2E5]
sample = sample[sample['SSC-A'] <= 5E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, #
            lw = 0, alpha = 0.3, legend = False, shade = True,
           label = '0 Dox, anti-CD4')


sample = FCMeasurement(ID='ctrl', datafile=filelist[1])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 3.4E5]
sample = sample[sample['SSC-A'] >= 2E5]
sample = sample[sample['SSC-A'] <= 5E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, #color = 'grey',
            lw = 0, alpha = 0.3, legend = False, shade = True,
           label = '0 Dox, anti-CD4')


sample = FCMeasurement(ID='ctrl', datafile=filelist[2])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 3.4E5]
sample = sample[sample['SSC-A'] >= 2E5]
sample = sample[sample['SSC-A'] <= 5E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, color = 'grey',
            lw = 0, alpha = 0.3, legend = False, shade = True)


for ax_ in [ax1]:
    ax_.set_yticks([])
    ax_.set_xlim(2,4.6)
    ax_.set_ylim(0,3)
    ax_.grid(axis='x', color= 'grey', alpha  = 0.2)#xcolor='0.95')

    # ax_.axes.get_xaxis().set_visible(False)
    ax_.axes.get_yaxis().set_visible(False)
    ax_.set_xlabel(None)
    ax_.set_xticks(np.log10([200,300,400,500,600,700,800,900,
                            2000,3000,4000,5000,6000,7000,8000,9000,
                            20000,30000,40000,50000,60000,70000,80000,90000,
                            200000,300000]), minor = True)
    ax_.set_xticks(np.log10([100,1000, 10000,100000]))
    ax_.set_xticklabels([])
    ax_.tick_params(length=8)

# %% [markdown]
# ## HL60 with NDi KRAB-dCas9_P2A_mCherry clonal line #8

# %%
filelist = \
['../../data/flow_cytometry/20200309_CD4_kd/KW-NDi-clone8_0umDox_antiCD4.fcs',
'../../data/flow_cytometry/20200309_CD4_kd/KW-NDi-clone8_gCD4_2umDox_antiCD4.fcs',
'../../data/flow_cytometry/20200309_CD4_kd/KW-NDi-clone8_gCD4_2umDox_antiCTRL.fcs',
]

# %%
fig, ax1 = plt.subplots(figsize=(4,3))

sample = FCMeasurement(ID='ctrl', datafile=filelist[0])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 3.4E5]
sample = sample[sample['SSC-A'] >= 2E5]
sample = sample[sample['SSC-A'] <= 5E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, #
            lw = 0, alpha = 0.3, legend = False, shade = True,
           label = '0 Dox, anti-CD4')


sample = FCMeasurement(ID='ctrl', datafile=filelist[1])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 3.4E5]
sample = sample[sample['SSC-A'] >= 2E5]
sample = sample[sample['SSC-A'] <= 5E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, #color = 'grey',
            lw = 0, alpha = 0.3, legend = False, shade = True,
           label = '0 Dox, anti-CD4')


sample = FCMeasurement(ID='ctrl', datafile=filelist[2])
sample = sample.data

# # gate out the noise and dead cells
sample = sample[sample['FSC-A'] >= 3.4E5]
sample = sample[sample['SSC-A'] >= 2E5]
sample = sample[sample['SSC-A'] <= 5E5]
# log values
sample['APC-Cy7-A_l'] = np.log10(sample['APC-Cy7-A'][sample['APC-Cy7-A'] > 0])

sns.kdeplot(sample["APC-Cy7-A_l"], ax = ax1, color = 'grey',
            lw = 0, alpha = 0.3, legend = False, shade = True)


for ax_ in [ax1]:
    ax_.set_yticks([])
    ax_.set_xlim(2,4.6)
    ax_.set_ylim(0,3)
    ax_.grid(axis='x', color= 'grey', alpha  = 0.2)#xcolor='0.95')

    # ax_.axes.get_xaxis().set_visible(False)
    ax_.axes.get_yaxis().set_visible(False)
    ax_.set_xlabel(None)
    ax_.set_xticks(np.log10([200,300,400,500,600,700,800,900,
                            2000,3000,4000,5000,6000,7000,8000,9000,
                            20000,30000,40000,50000,60000,70000,80000,90000,
                            200000,300000]), minor = True)
    ax_.set_xticks(np.log10([100,1000, 10000,100000]))
    ax_.set_xticklabels([])
    ax_.tick_params(length=8)
